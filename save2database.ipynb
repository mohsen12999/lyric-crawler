# %%
import sqlite3

# %%
# Connect to SQLite database (or create it if it doesn't exist)
conn = sqlite3.connect("my_database.db")

# Create a cursor object to execute SQL commands
cursor = conn.cursor()

# %%
# Create a artist table (if it doesn't already exist)
cursor.execute("""
    CREATE TABLE IF NOT EXISTS artists (
        id INTEGER PRIMARY KEY,
        name TEXT NOT NULL
    )
""")

# %%
# Retrieve and print the ids of all artists
cursor.execute("SELECT id FROM artists")
artists_id_rows = cursor.fetchall()

database_id_set = {t[0] for t in artists_id_rows}

print(len(database_id_set),database_id_set)
# Out:
# 0 set()

# %%
artist_id_from_file = set()
artist_dict = {}
with open("artists.csv", "r") as my_file:
    for file_line in my_file:
        artist_id_str = file_line.split(",")[0]
        if(artist_id_str.isnumeric()):
            artist_id = int(artist_id_str)
            artist_id_from_file.add(artist_id)
            artist_dict[artist_id] = file_line.split(",")[1]

print(len(artist_id_from_file), len(artist_dict))
# Out:
# 69135 69135

# %%
# Find Unique Elements from Both Lists
unique_elements = database_id_set ^ artist_id_from_file  
unique_elements_of_artist_id_from_file = unique_elements & artist_id_from_file

print(len(unique_elements_of_artist_id_from_file))
# Out:
# 69135

# %%
for id in unique_elements_of_artist_id_from_file:
    print((id,artist_dict[id]))
    cursor.execute("INSERT INTO artists (id, name) VALUES (?, ?)", (id, artist_dict[id]))
# Commit the changes
conn.commit()
# Out:
# (131072, 'stephen-bishop')
# (1310721, 'zeamsone-ft-vitali')
# (2, 'jay-z')
# (3, 'fabolous')
# (4, 'lil-wayne')
# (5, 'clipse')
# (1048580, 'kid-x-sa')
# (3014666, 'riccardo-antolini')
# (1572875, 'yampb')
# (1310732, 'benjiyeti')
# (13, 'gucci-mane')
# (1572878, 'dying-in-designer')
# (2359311, 'bbno-yung-gravy-lentra')
# (18, 'big-tymers')
# (20, 'ghostface-killah')
# (21, 'wu-tang-clan')
# (22, 'the-notorious-b-i-g')
# (655380, 'sayonara')
# (1048596, 'w-e-t-swedish-band')
# (1179672, 'gary-lightbody-johnny-mcdaid')
# (1703964, '123-trunko')
# (32, 'ol-dirty-bastard')
# (1048609, 'abu-yasser')
# (34, 'jadakiss')
# (655394, 'lowchano')
# (38, 'juvenile')
# (655398, 'yunggoth')
# (393256, 'matty-fresh')
# (655401, 'angelmaker')
# (42, 'the-game')
# (44, 'three-6-mafia')
# (45, 'eminem')
# (46, 'snoop-dogg')
# (655405, 'ateotu')
# (1310768, 'v-i-e-t-underground')
# (2621486, 'c-tangana-gipsy-kings-nicol-s-reyes-tonino-baliardo')
# (1441842, 'urban-life-worship')
# (2752563, 'el-alfa-chael-tivi-gunz')
# (3014700, 'curse-one-flict-g')
# (1048629, 'noggano')
# (1048630, 'erick-herv')
# (1703989, 'hundred-sins')
# (56, 'nas')
# (393272, 'hot-dad')
# (58, 'cormega')
# (59, '2pac')
# (1048633, '044-rose')
# (1703990, 'azahriah')
# (1703991, 'hundred-sins-azahriah')
# (63, 'fatlip')
# (64, 'bone-thugs-n-harmony')
# (67, 'jeezy')
# (68, 'kid-cudi')
# (69, 'j-cole')
# (70, 'mf-doom')
# (3145799, 'yoonmirae-bibi')
# (72, 'kanye-west')
# (73, 'jamie-foxx')
# (74, 'twista')
# (75, 'styles-p')
# (76, 'raekwon')
# (77, 'dmx')
# (78, 'juelz-santana')
# (79, 'jim-jones')
# (80, 'the-diplomats')
# (81, 'az')
# (82, 'diddy')
# (83, 'fat-joe')
# (655435, '2faces')
# (85, 't-i')
# (86, 'birdman')
# (655443, 'rich-forever-music')
# (88, 'rick-ross')
# (89, 'rihanna')
# (655444, 'kwor')
# (1048659, 'omer-adam')
# (92, 'nicki-minaj')
# (93, 'jaheim')
# (262238, 'elissa')
# (524383, 'hasan-shah')
# (393312, 'adam-snow')
# (1048673, 'eviatar-banai')
# (1179737, 'elias-abbas')
# (1048675, 'wild-culture-karmin')
# (100, 'pete-rock')
# (524389, 'alex-sparrow')
# (1179743, 'first-fragment')
# (103, 'big-l')
# (1048680, 'ronnie-cook')
# (105, 'outkast')
# (1048681, 'nlsn')
# (107, 'lil-jon')
# (108, '50-cent')
# (393325, 'thriii')
# (110, 'pharrell-williams')
# (111, 'ludacris')
# (112, 'timbaland')
# (1966186, 'zephanie-ebe-dancel')
# (1966193, 'emily-vu')
# (115, 'chamillionaire')
# (3145835, 'internet-money-yeat')
# (117, 'trina')
# (118, 'yo-gotti')
# (119, 'beanie-sigel')
# (655480, 'aron-can')
# (1048696, 'wild-culture-riley-pearce')
# (122, 'prodigy-of-mobb-deep')
# (123, 'dr-dre')
# (124, 'das-racist')
# (655482, 'tm-bax')
# (126, 'rakim')
# (127, 'scarface')
# (1048699, 'riley-pearce')
# (129, 'junior-m-a-f-i-a')
# (130, 'drake')
# (1048700, 'aryia')
# (132, 'usher')
# (1441920, 'xuitcasecity-eljay')
# (134, 'trillville')
# (135, 'lil-scrappy')
# (136, 'elementary')
# (1048712, '100-gecs')
# (2621569, 'kazusou-oda')
# (139, 'skee-lo')
# (140, 'khia')
# (141, 'lord-tariq-peter-gunz')
# (142, 'master-p')
# (3145868, 'puentes')
# (144, 'kelis')
# (655504, 'daezhon-moore')
# (1573008, 'ilkay-sencan')
# (147, 'lupe-fiasco')
# (148, 'nelly')
# (149, 'nate-dogg')
# (150, 'madvillain')
# (1310868, 'touliver')
# (2228371, 'philmon-lee')
# (3539094, 'youngs-teflon-tiny-boost-k-trap')
# (655515, 'yung-weej')
# (156, 'yasiin-bey')
# (157, 'akon')
# (158, 'dj-khaled')
# (1179806, 'kurdo-majoe')
# (1704096, 'ein-r')
# (161, 'big-pun')
# (162, 'sean-price')
# (1966241, '7sidebaby')
# (1966244, '7sidebaby-7sidebaby')
# (3276958, 'xavi-the-destroyer-luar-la-l')
# (3539109, 'slander-blackbear-bring-me-the-horizon')
# (167, 'project-pat')
# (262312, 'mudimbi')
# (169, 'warren-g')
# (170, 'kurupt')
# (393385, 'fyb-j-mane')
# (524457, 'tow-rs')
# (173, 'slaughterhouse')
# (1704103, 'kill-bill-rav')
# (1704109, 'cast-of-the-motion-picture-rent')
# (176, 'black-thought')
# (177, 'bilal')
# (178, 'aesop-rock')
# (179, 'joe-budden')
# (180, 'outlawz')
# (181, 'bob-dylan')
# (182, 'yelawolf')
# (183, 'ja-rule')
# (184, 'swizz-beatz')
# (262325, 'epi')
# (186, 'ice-cube')
# (187, 'tom-tom-club')
# (1179833, 'gest-rt-aber-geil-hirschwell')
# (1179836, 'vincent-malin')
# (190, 'mystikal')
# (191, 'too-hort')
# (192, 'm-o-p')
# (131263, 'kafon')
# (1048770, 'zodiac-signs')
# (195, 'memphis-bleek')
# (196, 'lloyd')
# (197, 'young-money')
# (198, 'jay-electronica')
# (3408073, 'venna-masego-mick-jenkins')
# (202, 'big-daddy-kane')
# (203, 'public-enemy')
# (204, 'foxy-brown')
# (524490, '2001-a-space-odyssey')
# (206, 'jae-millz')
# (1179853, 'jaws-of-love')
# (209, 'canibus')
# (210, 'das-efx')
# (211, 'red-cafe')
# (131281, 'matt-nathanson')
# (213, 'saul-williams')
# (214, 'lyrics-born')
# (215, 'blackalicious')
# (216, 'amg')
# (217, 'dj-quik')
# (393426, 'bahja-rodriguez')
# (219, 'guru')
# (220, 'gang-starr')
# (221, 'jean-grae')
# (1835223, 'edkhezee')
# (223, 'common')
# (224, 'j-dilla')
# (225, 'de-la-soul')
# (226, 'flavor-flav')
# (2228446, 'velocet')
# (228, 'method-man')
# (229, 'redman')
# (230, 'cassidy')
# (131301, 'game-of-thrones')
# (232, 'black-rob')
# (233, 'the-lox')
# (1179882, '4evr')
# (235, 'the-coup')
# (236, 'dead-prez')
# (1179885, 'ab')
# (238, 'immortal-technique')
# (393455, 'lo-stato-sociale')
# (240, 'reflection-eternal')
# (2097387, 'asylllum')
# (242, 'the-dramatics')
# (244, 'the-roots')
# (245, 'sheek-louch')
# (131316, 'bane')
# (2490614, '100k-mgmt')
# (1573112, 'terrell-hines')
# (249, 'ma-e')
# (250, 'freeway')
# (251, 'mobb-deep')
# (655611, 'dof-twogee-grc')
# (131325, 'chevy')
# (255, 'lloyd-banks')
# (257, 'waka-flocka-flame')
# (524546, 'said-the-sky')
# (1442050, 'hermitage-green')
# (260, 'oj-da-juiceman')
# (393477, 'pizzagirl')
# (262, 'joell-ortiz')
# (655622, 'r3hab-quintino')
# (1442056, 'ocean-evol')
# (655625, 'motta')
# (266, 'everlast')
# (267, 'q-tip')
# (268, 'black-sheep')
# (269, 'vampire-weekend')
# (270, 'gudda-gudda')
# (271, 'dorrough')
# (272, 'plies')
# (1573132, 'crooks')
# (393490, 'evelyn-turrentine-agee')
# (1835280, 'death-certificate')
# (276, 'madonna')
# (1966356, 'evu')
# (278, 'jeremih')
# (131350, 'ju-ara-mar-al')
# (2621711, '187-strassenbande-gzuz')
# (3014934, 'grigory-leps-vanya-dmitrienko')
# (282, 'mario')
# (3539223, 'robin-schulz-fil-bo-riva')
# (2058131, '2m')
# (1573149, 'oliverlygaming')
# (286, 'slim-thug')
# (287, 'mike-jones')
# (288, 'bun-b')
# (289, 'paul-wall')
# (2621725, 'c-tangana-carin-leon-adriel-favela')
# (291, 'xzibit')
# (293, 'yung-ralph')
# (296, 'j-r-writer')
# (655657, 'little-sis-nora')
# (298, 'hayley-williams')
# (131370, 'gardens-villa')
# (300, '40-cal')
# (301, 'dj-drama')
# (131373, 'the-coasters')
# (303, 'd12')
# (304, 'rich-boy')
# (305, 'jeru-the-damaja')
# (306, 'slick-rick')
# (307, 'rza')
# (308, 'naughty-by-nature')
# (131374, 'ballyhoo')
# (310, 'wiz-khalifa')
# (311, 'insane-clown-posse')
# (131382, 'tim-finn')
# (313, 'sugarhill-gang')
# (524594, 'chris-holsten')
# (315, 'lady-wray')
# (1442108, 'nublu')
# (2359609, 'officiallyta')
# (318, 'big-boi')
# (319, 'vinnie-paz')
# (320, 'r-a-the-rugged-man')
# (393534, 'raluka')
# (322, 'willie-the-kid')
# (2490687, 'juice-wrld-g-herbo')
# (3146048, 'marca-mp-becky-g')
# (2490693, 'rusherking-tiago-pzk-big-one')
# (326, 'trey-songz')
# (327, 'elzhi')
# (2490695, 'kinder-malo-pimp-flaco-blackthoven')
# (329, 'beastie-boys')
# (1048905, 'heidi-mollenhauer')
# (3277125, 'murda-uzi')
# (332, 'empire-of-the-sun')
# (1442124, 'digital-farm-animals-shaun-frank-dragonette')
# (334, 'justin-timberlake')
# (335, 'ron-browz')
# (655695, 'jban-2turnt')
# (337, 't-pain')
# (338, 'busta-rhymes')
# (339, 'm-a')
# (340, 'pras')
# (524628, 'gordi')
# (1573201, '803-paul')
# (1573202, 'suriel-hess')
# (344, 'consequence')
# (345, 'p-nk')
# (2883930, 'invent-ykt')
# (347, 'grandmaster-flash-the-furious-five')
# (350, 'krayzie-bone')
# (351, 'george-clinton')
# (131422, 'buddy-guy')
# (353, 'chris-martin')
# (354, 'black-star')
# (655710, 'kream')
# (1048928, 'william-singe-conor-maynard')
# (357, 'justin-bieber')
# (358, 'mary-j-blige')
# (359, 'youngblood-z')
# (524646, 'i-rem-derici')
# (655719, 'uicideboy-germ')
# (362, 'alicia-keys')
# (1048935, 'sob-x-rbe')
# (1048939, 'dj-critical-hype')
# (365, 'john-legend')
# (366, 'klashnekoff')
# (367, 'masta-ace')
# (368, 'the-streets')
# (369, 'isaac-hayes')
# (1966449, 'bodiev')
# (1048947, 'slimmy-b')
# (372, 'fugees')
# (373, 'terror-squad')
# (1048948, 'lil-dank')
# (375, 'ne-yo')
# (1311095, 'rampaz-slim-g')
# (377, 'geto-boys')
# (2359672, 'lenny-tav-rez-be-le')
# (379, 'trick-daddy')
# (2490739, 'reik-christian-nodal')
# (381, 'cody-chesnutt')
# (382, 'lil-flip')
# (383, 'david-banner')
# (1180029, 'rosegold-dk')
# (385, 'atmosphere')
# (1048961, 'daboii')
# (387, 'above-the-law')
# (388, 'talib-kweli')
# (655749, 'canl-tv-izle-hd-tv-web-tv-kesintisiz-tv-televizyon-izle')
# (390, 'mickey-factz')
# (393607, '9muses')
# (392, 'snow')
# (393609, 'orhan-hakalmaz')
# (1048962, 'yhung-t-o')
# (395, 'jay-sean')
# (396, 'wale')
# (397, 'skillz')
# (393612, 'elijah-kelley')
# (1573254, 'osbs')
# (2359694, 'chelsea-collins-24kgoldn')
# (401, 'ugk')
# (402, 'young-buck')
# (403, 'n-o-r-e')
# (404, 'wc')
# (405, 'e-40')
# (406, 'young-dro')
# (131473, 'erra')
# (408, 'm-i-m-s')
# (409, 'charles-hamilton')
# (1442194, 'papi-trujillo')
# (411, 'lil-kim')
# (412, 'i-20')
# (413, 'chiddy-bang')
# (1048987, 'jeremih-chance')
# (415, 'bobby-v')
# (416, 'devin-the-dude')
# (1442200, 'evan-and-eris')
# (1966491, 'diplomacy')
# (1966496, '73-pack')
# (420, 'blu')
# (2884005, 'zizzy-adrian-be-ceaese')
# (424, 'papa-roach')
# (425, 'black-eyed-peas')
# (426, 'army-of-the-pharaohs')
# (3277224, 'kabe-x-miszel')
# (428, 'kc-jojo')
# (524717, 'sinan-ak-l')
# (430, 'lord-finesse')
# (2621868, 'jd-pantoja-kim-loaiza')
# (432, 'chris-webby')
# (1704369, 'moira-dela-torre-jason-marvin')
# (1704370, 'afourteen')
# (435, 'dido')
# (436, 'ray-j')
# (437, 'bobby-brackins')
# (438, 'chris-brown')
# (440, 'boyz-ii-men')
# (1835450, 'original-broadway-cast-of-tootsie')
# (443, 'p-money')
# (444, 'afu-ra')
# (3277244, 'timcast')
# (446, 'miguel')
# (447, 'lady-gaga')
# (448, 'lauryn-hill')
# (449, 'gemstones')
# (450, 'celph-titled')
# (451, 'rjd2')
# (2621891, 'majestic-boney-m')
# (453, 'asher-roth')
# (655813, 'luxe')
# (455, 'lil-b')
# (655815, 'ernie-bigdaws')
# (457, 'diamond-d')
# (458, 'eve')
# (459, 'robin-thicke')
# (460, 'ace-hood')
# (1442248, 'paris-berelc')
# (1704390, 'hex-rated')
# (524751, 'hjerteslag')
# (464, 'tha-dogg-pound')
# (2621898, 'peach-prc')
# (466, 'apathy')
# (467, 'wyclef-jean')
# (524755, 'hv71')
# (2621907, 'ovi-myke-towers-aleman')
# (1311190, 'sophie-ita')
# (471, 'royce-da-5-9')
# (472, 'lowkey')
# (473, 'ying-yang-twins')
# (474, 'lil-jon-the-east-side-boyz')
# (475, 'pac-div')
# (524762, 'irish-rock-music')
# (3146202, 'qonyratbay-fam')
# (478, 'the-firm')
# (1049054, '55bagz')
# (480, 'the-beatnuts')
# (481, 'k-naan')
# (1573343, 'chris-d-elia')
# (2097632, 'dkb')
# (484, 'kxng-crooked')
# (485, 'luniz')
# (486, 'bushwick-bill')
# (487, 'chino-xl')
# (488, 'john-mayer')
# (1573352, 'jesus-piece')
# (490, 'uncle-murda')
# (491, 'big-k-r-i-t')
# (492, 'big-sean')
# (493, 'seventh-floor-crew')
# (262637, 'buffy-sainte-marie')
# (1180141, 'prettymuch')
# (496, 'eazy-e')
# (1704433, 'zlatan-burna-boy')
# (498, 'beyonc')
# (2228722, 'owen-barney')
# (500, 'bruno-mars')
# (501, 'sage-francis')
# (502, 'non-prophets')
# (503, 'epmd')
# (504, '112')
# (505, 'yukmouth')
# (506, 'tech-n9ne')
# (507, 'gza')
# (508, 'inspectah-deck')
# (509, 'mr-porter')
# (1049081, 'justin-snow')
# (1311224, 'eem-triplin')
# (512, 'jedi-mind-tricks')
# (2621945, 'yoseob-jeong-eun-ji')
# (2097666, '102-boyz-65-goonz')
# (515, 'jus-allah')
# (517, 'the-last-emperor')
# (1573382, 'landspeed')
# (519, 'a-tribe-called-quest')
# (520, 'camp-lo')
# (521, 'the-pharcyde')
# (522, 'souls-of-mischief')
# (524809, 'magic-city-hippies')
# (1442316, 'mc-goremika')
# (528, 'richie-rich')
# (529, 'spice-1')
# (530, 'charlie-wilson')
# (393746, 'to-e-proeski')
# (532, 'tonedeff')
# (533, 'aerosmith')
# (534, 'cunninlynguists')
# (535, 'r-kelly')
# (536, 'nick-cannon')
# (524817, 'montaigne')
# (538, 'chrisette-michele')
# (524819, 'yumi-lacsamana')
# (655898, 'vinny-west')
# (655901, 'carmody')
# (1180187, 'neil-frances')
# (1704471, 'nurminski')
# (544, 'blue-scholars')
# (545, 'mc-paul-barman')
# (546, 'loaded-lux')
# (547, 'killer-mike')
# (131617, 'zz-knyazz')
# (655904, 'nigativ')
# (655907, 'la-porsha-renae')
# (655908, 'trent-harmon')
# (524840, 'wolf-colony')
# (553, 'lil-twist')
# (554, 'tyga')
# (555, 'ca-his')
# (556, 'tony-yayo')
# (393771, 'kumar-sanu')
# (655909, 'tresor')
# (655919, 'chada-x-sztoss')
# (560, 'elton-john')
# (561, 'eagles')
# (562, 'led-zeppelin')
# (563, 'queen')
# (1049134, 'kharfi')
# (1049135, 'u-s-music')
# (566, 'fre-h-short-dawg')
# (567, 'mc-jin')
# (262711, 'bert-jansch')
# (1180212, 'endo-pr')
# (1180216, 'mariya-takeuchi')
# (571, 'mc-chris')
# (572, 'unkle')
# (262717, 'erica-campbell')
# (655932, 'phfat-al-bairre')
# (1966651, 'abraham-mateo-sof-a-reyes')
# (1049152, 'wendy')
# (1049153, 'seulgi')
# (524869, 'yukon-gjelseth')
# (2097733, 'okayceci')
# (583, 'saigon')
# (584, 'chali-2na')
# (585, 'roots-manuva')
# (586, 'the-beatles')
# (588, 'z-ro')
# (589, 'bon-iver')
# (1049164, 'alex-brightman')
# (655951, 'bri-babineaux')
# (597, 'brandon-flowers')
# (598, 'neil-young')
# (599, 'the-killers')
# (600, 'arcade-fire')
# (601, 'the-doors')
# (393818, 'george-michael-elton-john')
# (604, 'radiohead')
# (605, 'murs')
# (606, 'keak-da-sneak')
# (131676, 'dan-romer')
# (609, 'edward-maya')
# (1704546, 'die-mondez')
# (1180259, 'jake-webber')
# (1573476, 'stereo-wall')
# (1180261, 'sam-and-colby')
# (614, 'yung-joc')
# (2097764, 'diasafari')
# (1311336, 'gspd-m-mn-kc-n')
# (617, 'black-milk')
# (619, 'the-doobie-brothers')
# (620, 'i-d')
# (1442411, 'hussa')
# (622, 'cali-swag-district')
# (524912, 'hollywood-anderson')
# (1573490, 'dziarma')
# (627, 'the-lady-of-rage')
# (628, 'pitbull')
# (629, 'leonard-cohen')
# (630, 'rivers-cuomo')
# (631, 'blind-melon')
# (632, 'green-day')
# (633, 'dom-kennedy')
# (262775, 'empire-empire-i-was-a-lonely-estate')
# (131701, 'julia-engelmann')
# (1049212, 'david-fergie-ferguson')
# (637, 'guns-n-roses')
# (638, 'stalley')
# (1311355, 'towy')
# (640, 'king-los')
# (641, 'lynyrd-skynyrd')
# (642, 'tash')
# (643, 'pusha-t')
# (644, 'animal-collective')
# (645, 'chingy')
# (524929, 'hanna-j-rver')
# (1966724, 'whole-truth')
# (648, 'the-clash')
# (649, 'd-lo')
# (656010, 'jesse-baez')
# (651, 'mac-dre')
# (652, 'niia')
# (653, 'fiona-apple')
# (654, 'mike-posner')
# (1049228, 'yslog')
# (656, 'sir-mix-a-lot')
# (657, 'rappin-4-tay')
# (658, 'the-national')
# (659, 'sublime')
# (660, 'prince')
# (131728, 'rachid-taha')
# (262800, 'hunters-collectors')
# (663, 'nina-sky')
# (262801, 'ina-wroldsen')
# (665, 'major-lazer')
# (262804, 'local-h')
# (667, 'travie-mccoy')
# (668, 'digital-underground')
# (669, 'adam-levine')
# (524953, 'hazama')
# (671, 'melanie-fiona')
# (656026, 'until-we-are-ghosts')
# (1180320, 'buck-meek')
# (1573538, 'yuju')
# (675, 'deltron-3030')
# (676, 'coolio')
# (2491041, 'g-nay-m-t-llimova')
# (3015326, 'chefin')
# (679, 'sting')
# (680, 'craig-david')
# (2097832, 'half-an-orange-ephixa')
# (682, 'faith-evans')
# (3539625, 'troy-javelona')
# (684, 'pharoahe-monch')
# (685, 'tyler-the-creator')
# (686, 'earl-sweatshirt')
# (688, 'slum-village')
# (2359985, 'urban-flow')
# (691, 'sade')
# (262836, 'kandace-springs')
# (393908, 'hyper')
# (694, 'pink-floyd')
# (695, 'hittman')
# (1835701, 'avicii-imagine-dragons')
# (2097844, 'unique-syntax')
# (698, 'kevin-mccall')
# (699, 'ryan-leslie')
# (131770, 'karen-van-der-zee')
# (1704636, 'moonica-mac')
# (2622135, 'ivers')
# (703, 'foster-the-people')
# (704, 'fort-minor')
# (1311423, 'jt-x-yung-miami')
# (1180354, 'jimin-bts-jungkook')
# (708, 'king-geedorah')
# (131781, 'sarius')
# (1966788, 'skilla-baby')
# (711, 'misfits')
# (712, 'viktor-vaughn')
# (713, 'will-i-am')
# (714, 'method-man-redman')
# (262856, 'dylan-scott')
# (1049287, 'volkan')
# (717, 'emily-dickinson')
# (1966791, 'triplprincesss-fluffy-curl-cd-r')
# (719, 'cappadonna')
# (720, 'labrinth')
# (721, 'tinie-tempah')
# (722, 'e-e-cummings')
# (723, 'blur')
# (724, 'locksmith')
# (725, 'dylan-thomas')
# (726, 'william-butler-yeats')
# (727, 'nikki-giovanni')
# (131791, 'upfront-mc')
# (729, 'john-berryman')
# (730, 'fashawn')
# (731, 'omen')
# (732, 'craig-smith')
# (131802, 'unknxwn')
# (262876, 'pup-band')
# (1311449, 'katz-oso')
# (736, 'diggy')
# (737, 'bloodhound-gang')
# (131808, 'needtobreathe')
# (739, 'rumi')
# (740, 'sean-paul')
# (131813, 'gum')
# (742, 't-s-eliot')
# (743, 'deadmau5')
# (744, 'morgan-page')
# (745, 'bow-wow')
# (746, 'jimi-hendrix')
# (747, 'n-e-r-d')
# (748, 'goodie-mob')
# (749, 'the-white-stripes')
# (131816, 'jamie-grace')
# (751, 'big-rube')
# (525033, 's-ren-poppe')
# (1049328, 'jaloner')
# (754, 'nino-bless')
# (755, 'flobots')
# (1573611, 'wifi24k')
# (757, 'wayne-wonder')
# (758, 'cyhi')
# (759, 'keri-hilson')
# (1049335, 'pastor-t-l-barrett-and-the-youth-for-christ-choir')
# (1180409, 'dove-cameron-sofia-carson-cameron-boyce-booboo-stewart')
# (1573625, 'ufo-ivo')
# (763, 'phoenix')
# (764, 'mgmt')
# (765, 'ramones')
# (656124, 'amber-mark')
# (1966845, 'vista-pal-lago')
# (768, 'various-artists')
# (3015425, '3one')
# (1311490, 'chelji')
# (772, 'rockstar')
# (773, 'virtuoso')
# (774, 'the-rolling-stones')
# (525061, 'unik-4')
# (3539717, 'rory-ari-lennox-james-fauntleroy')
# (777, 'samuel-taylor-coleridge')
# (778, 'robert-frost')
# (779, 'andrew-marvell')
# (780, 'vado')
# (782, 'keyshia-cole')
# (783, 'janelle-mon-e')
# (2229007, 'omb-bloodbath-maxo-kream')
# (785, 'gravediggaz')
# (131859, 'benny-hill')
# (2229014, '30-on-the-beat')
# (1049367, 'ahn-ye-eun')
# (1180440, 'yungdork')
# (793, 'lost-boyz')
# (795, 'shyheim')
# (1704731, 'veli-sahiti-trix')
# (799, 'rap-genius-editors')
# (800, 'bee-gees')
# (2884383, 'kalim-layla')
# (803, 'kurtis-blow')
# (656163, 'pa-way')
# (805, 'miley-cyrus')
# (806, 'doris-day')
# (656166, 'harpi-m-u-r')
# (809, '2-live-crew')
# (810, 'obie-trice')
# (811, 'la-roux')
# (812, 'rhymefest')
# (394028, 'anand-raj-anand')
# (814, 'andre-nickatina')
# (815, 'boogie-down-productions')
# (816, 'ginuwine')
# (656173, 'youngboy-never-broke-again')
# (656178, 'rickey-f')
# (1180462, 'o-trago')
# (820, 'mac-miller')
# (2229036, 'el-alfa-chael')
# (822, 'william-blake')
# (823, 'milli-vanilli')
# (824, 'frank-sinatra')
# (656182, 'wiktoria')
# (1704760, 'ekkstacy')
# (827, 'moses-prophet')
# (828, 'ricky-martin')
# (829, 'eurythmics')
# (2229045, 'el-alfa-farruko')
# (831, 'fat-trel')
# (1573696, 'neo-pist-a-khea')
# (1573697, 'haachim-tzabari')
# (835, 'michael-jackson')
# (2884419, 'ruki-vverh-hammali-navai')
# (3015491, 'nominal-dingus')
# (2491208, 'nyluu')
# (842, 'william-shakespeare')
# (843, 'u-t-p')
# (1835851, 'mazzeratti-duke')
# (2491212, 'r-j-khan')
# (846, 'marley-marl')
# (847, 'kool-g-rap')
# (848, 'll-cool-j')
# (849, 'glasses-malone')
# (850, 'styles-of-beyond')
# (851, 'unk')
# (852, 'peter-fox')
# (853, 'b-o-b')
# (854, 'the-west-coast-rap-all-stars')
# (656206, 'jeremy-shada')
# (1180495, 'brad-cox')
# (1704789, 'vahni-capildeo')
# (1704790, 'dadaiseverywhere')
# (859, 'gorilla-zoe')
# (860, 'gorillaz')
# (861, 'the-crooklyn-dodgers')
# (1049438, 'ily-swe')
# (1704799, 'rocstrong')
# (864, 'curtis-mayfield')
# (656224, 'dermot-kennedy')
# (2098010, 'bigantdog-raps')
# (2360158, 'blackpink-selena-gomez')
# (2884449, 'original-juan-gordo-del-funk')
# (869, 'jagged-edge')
# (1442663, 'cast-of-the-motion-picture-renttttttt')
# (1049449, 'kotb')
# (874, 'tim-dog')
# (875, 'young-cash')
# (1442665, '12anti-box12-x-156-nitonb-x-madmax')
# (882, 'kidd-kidd')
# (263027, 'ncaa-football')
# (884, 'demarco')
# (885, 'vybz-kartel')
# (886, 'tarrus-riley')
# (887, 'the-kinks')
# (888, 'mutemath')
# (394098, 'the-citizens-of-halloween')
# (1049458, 'kmn-gang')
# (1442682, 'zhr')
# (263037, 'tom-misch-carmody')
# (897, 'spose')
# (899, 'weird-al-yankovic')
# (2229124, 'alex-blue')
# (2491268, 'leonz')
# (131977, 'zeno')
# (525194, 'zillah-totte')
# (1049481, 'wooli')
# (3408779, 'blp-kosher')
# (909, 'erykah-badu')
# (131982, 'meaku')
# (1573773, 'thevivi')
# (922, 'bob-marley')
# (924, 'far-east-movement')
# (3015581, 'rebelde-la-serie-andrea-chaparro-jeronimo-cantillo')
# (926, 'william-carlos-williams')
# (928, 'girl-talk')
# (929, 'webbie')
# (930, 'foxx-a-million')
# (931, 'boosie-badazz')
# (132004, 'embrace')
# (933, 'sean-kingston')
# (934, 'onerepublic')
# (1049505, 'page-four')
# (936, 'kardinal-offishall')
# (937, 'flynt-flossy')
# (938, 'yung-humma')
# (939, 'freddie-gibbs')
# (940, 'the-lonely-island')
# (941, 'vince-staples')
# (942, 'house-of-pain')
# (943, 'depeche-mode')
# (944, 'marvin-gaye')
# (1049521, 'kris-kross-amsterdam-conor-maynard')
# (946, 'killah-priest')
# (1049523, 'frsh')
# (1049524, 'wande')
# (1573805, 'jappi')
# (950, 'fergie')
# (951, 'the-world-famous-tony-williams')
# (952, 'amiri-baraka')
# (953, 'gil-scott-heron')
# (1311670, 'beba')
# (3015603, 'rebelde-la-serie-andrea-chaparro-alejandro-puente')
# (956, 'eric-turner')
# (957, 'cyne')
# (958, 'sufjan-stevens')
# (1049535, 'upchurch')
# (1967041, 'radio-company')
# (964, 'tlc')
# (1180613, 'orion-sun')
# (1442758, 'residente-dillon-francis')
# (2098116, 'presence-2')
# (969, 'jasmine-mans')
# (971, 'the-high-mighty')
# (972, 'king-skam')
# (656331, 'juhn')
# (974, 'n-w-a')
# (1311693, 'naisten-pojat')
# (525264, 'the-boys-from-nazareth')
# (977, 'masta-killa')
# (2098125, 'jhay-cortez-anuel-aa-j-balvin')
# (979, 'bo-burnham')
# (980, 'b-j-thomas')
# (2491341, 'svnv')
# (132054, 'a-touch-of-class')
# (3539920, 'guus-meeuwis-de-getuigen')
# (132056, 'ogs')
# (1049561, 'kiaz')
# (986, 'dwele')
# (3539927, 'awich-ozworld-chico-carlito')
# (1049564, 'r-ot')
# (989, 'joni-mitchell')
# (3539931, 'lil-tjay-fridayy-and-khi-infinite')
# (995, 'invincible')
# (998, 'b-real')
# (1001, 'natasha-bedingfield')
# (394217, 'nicole-milik')
# (1004, 'wallace-stevens')
# (656365, 'globelamp')
# (525294, 'nursery-rhymes')
# (1007, 'dj-clue')
# (1008, 'pastor-troy')
# (1573868, 'tom-meighan')
# (1010, 'xv')
# (525298, 'mia-borisavljevi')
# (1012, 'del-the-funky-homosapien')
# (1180658, 'justin-rarri')
# (1014, 'bishop-lamont')
# (1015, 'chester-bennington')
# (1016, 'swedish-house-mafia')
# (656374, 'between-you-me')
# (1018, 'lil-cuete')
# (1573879, 'itsunknownmf')
# (1020, 'jhen-aiko')
# (1021, 'phonte')
# (1022, 'evidence')
# (1023, 'paris-rap')
# (1024, 'chubb-rock')
# (132096, 'tamaryn')
# (132097, 'bet')
# (2360320, '1-800-pain')
# (2622466, 'stranger-white')
# (1029, 'philip-larkin')
# (3146749, 'marissa-emo')
# (3277824, 'oven-nor')
# (1035, 'k-os')
# (1038, 'dev')
# (1039, 'mc-hammer')
# (3408912, '7moda')
# (1042, 'm-i-a')
# (1043, 'bizarre')
# (132114, 'zachariah')
# (1045, 'binary-star')
# (1180693, 'dimitri-vegas-like-mike-vs-david-guetta')
# (1836052, 'denzel-m')
# (2884630, 'neiked-mae-muller-polo-g')
# (1836058, 'twomad')
# (1051, 'mario-winans')
# (1052, 'britney-spears')
# (1054, 'akinyele')
# (1056, 'large-professor')
# (1057, 'tank')
# (1049634, 'kezah')
# (1442849, 'harvest')
# (1060, 'u-god')
# (132133, 'world-championship-wrestling')
# (132134, 'merle-haggard')
# (1442854, 'valkeat')
# (1704999, 'sofia-wylie')
# (2622502, 'zafrir-afrojack')
# (1705002, 'tankhead-ikabod-veins')
# (1068, 'cage')
# (2753581, 'rakz-uk')
# (1070, 'el-p')
# (1071, 'lewis-carroll')
# (1072, 'diabolic')
# (1073, 'juicy-j')
# (1074, 'sticky-fingaz')
# (1075, 'trae-tha-truth')
# (132148, 'david-cook')
# (1705009, 'craig-xen-cooliecut-killstation')
# (1049654, 'defqwop')
# (1705012, 'kid-trunks-flyboy-tarantino-robb-bank')
# (1080, 'walt-whitman')
# (1081, 'flo-rida')
# (1082, 'ti-sto')
# (1083, 'gym-class-heroes')
# (656443, 'summer-salt')
# (1180732, 'egovert')
# (1049662, 'yung-vegan')
# (1087, 'young-cellski')
# (1088, 'brotha-lynch-hung')
# (1089, 'hieroglyphics')
# (1180737, 'lostnunbound')
# (1091, 'dilated-peoples')
# (1092, 'purple-ribbon-all-stars')
# (1705022, 'xxxtentacion-bass-santana-kin-oul-reddz')
# (1705024, 'bass-santana-flyboy-tarantino-kid-trunks-craig-xen')
# (1705027, 'bass-santana-kin-oul-robb-bank-bhris-absentwill')
# (1705028, 'toobrokeforfiji')
# (1097, 'hellogoodbye')
# (1705033, 'bass-santana-xxxtentacion-ski-mask-the-slump-god')
# (2491459, 'atarashii-gakko')
# (132172, 'al-ghazali')
# (1102, 'skylar-grey')
# (525390, 'zara-mcfarlane')
# (1104, 'carly-simon')
# (1105, 'westside-connection')
# (1106, 'fio-baby')
# (1107, 'b-b-king')
# (1108, 'aretha-franklin')
# (394320, 'sebastian-kole')
# (394321, 'alessia-cara')
# (1111, 'craig-mack')
# (1049684, 'hate-drugs')
# (525401, 'zara-coz')
# (1705041, 'audrey-mika')
# (1705044, 'tankhead-ratchet-roach-cooliecut-kid-trunks-flyboy-tarantino-craig-xen-sb-kin-oul-bass-santana-rawhool-mane')
# (1116, 'chop')
# (1049693, '54')
# (1118, 'faramarz-aslani')
# (525407, 'hans-martin')
# (394336, 'uochi-toki')
# (1121, 'black-sabbath')
# (1122, 'main-source')
# (1180768, 'sunny-mac')
# (1124, 'run-dmc')
# (1125, 'pete-rock-c-l-smooth')
# (1705053, 'xxxtentacion-killstation')
# (1705054, 'kin-oul-cooliecut-rawhool-mane')
# (656488, 'area21')
# (1129, 'the-d-o-c')
# (1130, 'little-brother')
# (1049706, 'poky')
# (1132, 'damian-marley')
# (1180776, 'may-band')
# (2098285, 'yang-joon-il')
# (656495, 'coca-vango')
# (1136, 'ar-ab')
# (1137, 'vanilla-ice')
# (1138, 'the-beach-boys')
# (1705073, 'yung-tylon')
# (1140, 'uffie')
# (1141, 'fiend')
# (1143, 'n-dubz')
# (525432, 'justin-quiles')
# (1145, 'nero')
# (1146, 'patti-labelle')
# (132218, 'yu-gi-oh')
# (1148, 'will-smith')
# (1149, 'rbx')
# (1967228, 'sido-santos')
# (1154, 'thomas-jefferson')
# (263298, 'gustavo-cerati')
# (1158, 'yaki-kadafi')
# (1159, 'tim-chantarangsu')
# (1163, 'maverick-sabre')
# (1164, 'professor-green')
# (1166, 'the-black-keys')
# (1167, 'johnny-cash')
# (1574030, 'khang-vi-t')
# (1169, 'lcd-soundsystem')
# (1170, 'mumford-sons')
# (1171, 'yeasayer')
# (1172, 'shad')
# (1173, 'capone-n-noreaga')
# (1174, 'kings-of-leon')
# (132247, 'patrizio-buanne')
# (1176, 'toby-keith')
# (1177, 'taylor-swift')
# (656529, 'ledger')
# (1179, 'mavis-staples')
# (1180, 'mann')
# (1181, 'the-dream')
# (1182, 'robyn')
# (1183, 'curren-y')
# (1184, 'example')
# (1185, 'lily-allen')
# (1186, 'iyaz')
# (132255, 'guordan-banks')
# (132259, 'b-e-r')
# (1189, 'blumentopf')
# (1190, 'domo-genesis')
# (1191, 'jurassic-5')
# (263336, 'serial-podcast')
# (1049764, 'vnubix')
# (1194, 'soulja-boy')
# (1195, 'katy-perry')
# (1196, 'ed-o-g-da-bulldogs')
# (263339, 'benjamin-clementine')
# (1198, 'john-holt')
# (1199, 'steel-pulse')
# (1049776, 'pitto-stail')
# (394417, 'nikos-vertis')
# (1180843, 'talha-anjum')
# (1203, 'eyedea-abilities')
# (1204, 'tarkan')
# (1205, 'mariah-carey')
# (1206, 'j-kwon')
# (2622647, 'croftblock')
# (3540147, 'lau-noah-jacob-collier')
# (1210, 'truth-hurts')
# (1211, 'christina-aguilera')
# (3015867, '23-c-gambino')
# (1213, 'tha-joker-us')
# (1180861, 'umair-khan')
# (1215, 'max-b')
# (1216, 'anita-baker')
# (1180862, 'baby-soulja')
# (1218, 'trick-trick')
# (1311935, 'olivia-buckles')
# (1220, 'necro')
# (1574083, 'lil-droptop-golf-cart')
# (1222, 'the-miracles')
# (1223, 'smokey-robinson')
# (1836230, 'hikiray')
# (1225, 'c-bo')
# (394442, 'hache-p')
# (1049804, 'quote-the-raven')
# (2098382, 'zaza-enca-mixey')
# (656591, 'ili')
# (1232, 'harry-belafonte')
# (2622670, 'addison-rae')
# (1234, 'jazmine-sullivan')
# (1235, 'marsha-ambrosius')
# (1236, 'teyana-taylor')
# (132309, 'the-roches')
# (656596, 'ingrid')
# (394455, 'alban-skenderaj')
# (1240, 'lady-sovereign')
# (1180883, 'bmye')
# (1311957, 'haiku-hands')
# (1243, 'do-or-die')
# (1311964, 'mars-no')
# (1245, 'lsg-r-b')
# (394461, 'mundo-segundo-sam-the-kid')
# (1443033, 'ne-yo-bebe-rexha-stefflon-don')
# (1967320, '9hmet')
# (1249, 'teddy-pendergrass')
# (1250, 'peter-tosh')
# (1251, 'dem-franchize-boyz')
# (525537, 'tekno')
# (656609, 'alfa-mist')
# (1311972, 'gift-blessing')
# (2753762, 'cizzo')
# (1256, 'ice-t')
# (1257, 'brother-ali')
# (2491626, 'plug-ita')
# (1574123, 'usuarios-de-genius-en-espa-ol')
# (1260, 'dry')
# (1261, 'sexion-d-assaut')
# (1262, 'hodgy')
# (1263, 'nipsey-hussle')
# (1264, 'mf-grimm')
# (1265, 'm-dine')
# (1266, 'young-chris')
# (1267, 'dame-dash')
# (263409, 'cynthia-erivo')
# (1269, 'krs-one')
# (1270, 'felt')
# (1271, 'mac-lethal')
# (263413, 'fit-for-a-king')
# (1273, 'kery-james')
# (1274, 'nickelus-f')
# (263417, 'johnny-winter')
# (263419, 'honor')
# (1277, 'dangerdoom')
# (1278, 'lakutis')
# (263422, '21-boy')
# (656637, 'aribeatz')
# (1281, 'papoose')
# (1282, 'booba')
# (263426, 'crooked-i')
# (656638, 'oro-grezzo')
# (656643, 'clayton-jennings')
# (1286, 'orelsan')
# (1287, 'yung-wun')
# (1288, 'ruff-ryders')
# (1289, 'andy-milonakis')
# (1180934, 'joy-oladokun')
# (1180936, 'jona-alk')
# (2360584, 'corook')
# (1293, 'gyptian')
# (2098445, '290')
# (1297, 'jayo-felony')
# (1049875, 'underlover')
# (2098452, 'laica')
# (525589, 'lbsb')
# (1302, 'kelly-rowland')
# (1303, 'la-fouine')
# (1304, 'k-i-z')
# (1049880, 'poobon')
# (2491668, 'nathan-dawe-little-mix')
# (1308, 'hopsin')
# (1310, 'mc-solaar')
# (1311, 'teenage-fanclub')
# (263454, 'tit-s')
# (656670, 'alex-lacamoire')
# (3278110, 'origami-ultra')
# (1315, 'hell-rell')
# (2622755, 'dwllrs')
# (1317, 'cypress-hill')
# (1318, 'john-denver')
# (1319, 'meek-mill')
# (656677, 'jadu-heart')
# (1321, 'swizzz')
# (1322, 'company-flow')
# (2884907, 'holly-johnson-richard-e-grant')
# (1323, 'naeto-c')
# (656683, 'stevie-ray')
# (1325, 'olivia')
# (1326, 'organized-konfusion')
# (1180968, 'janelle-mon-e-jidenna')
# (656688, 'death-protopunk-band')
# (1329, 'auburn')
# (1330, 'rubberbandits')
# (1331, 'the-cool-kids')
# (1333, 'proof')
# (1049910, 'young-marco')
# (1335, 'psycho-realm')
# (1336, 'babyface')
# (1337, 'afroman')
# (263479, 'lauren-aquilina')
# (656695, 'rauw-alejandro')
# (1340, 'estelle')
# (263485, 'kari-kimmel')
# (1342, 'jodeci')
# (656696, 'lyanno')
# (1705272, 'rusherking')
# (1836352, 'v-moto-rock')
# (3409215, 'hales')
# (1348, 'akala')
# (394565, 'the-bomb-digz')
# (1836358, 'x1xbuch')
# (1443143, 'machine-gun-kelly-x-ambassadors-bebe-rexha')
# (1181001, 'because')
# (1355, 'travis-porter')
# (1358, 'keys')
# (1574222, 'cai-xu-kun')
# (2098512, 'alz-x-38')
# (1362, 'belly')
# (1363, 'bei-maejor')
# (1705300, 'liberty-haze')
# (1181014, 'o-neill-hudson')
# (1049943, 'dsm')
# (2491737, 'neet-neet')
# (1370, 'fat-tony')
# (1371, 'smash-mouth')
# (1049948, 'mcfly-carlito')
# (1574237, '6th')
# (3409246, 'xcho-ramil')
# (1375, 'mister-you')
# (394592, 'beach-slang')
# (3540318, '4-4c')
# (2098531, 'khalid-disclosure')
# (1705319, 'zivert')
# (3278185, '38danielriche')
# (1387, 'illogic')
# (1388, 'doseone')
# (1389, 'why')
# (1390, 'clouddead')
# (525676, 'klass')
# (656748, 'wiz-khalifa-ty-dolla-ign')
# (1393, 'dizzee-rascal')
# (1312111, 'whethan-dua-lipa')
# (394611, 'chris-stapleton')
# (1574256, 'noah-cyrus-max')
# (1397, 'giggs')
# (1398, 'devlin')
# (132469, 'the-sound-of-animals-fighting')
# (1400, 'tinchy-stryder')
# (1401, 'lecrae')
# (525690, 'anteros')
# (1403, 'jay-rock')
# (1404, 'yael-naim')
# (1405, 'shakira')
# (1406, 'kevin-rudolf')
# (1407, 'shawty-lo')
# (1408, 'maino')
# (1443199, 'jossan')
# (1412, 'huff-n-doback')
# (1413, 'le1f')
# (1414, 'third-eye-blind')
# (1312132, 'jacob-banks-louis-the-child')
# (1312133, 'jamie-dornan')
# (1181068, 'shoplyfter')
# (1421, 'kendrick-lamar')
# (1422, 'danny-brown')
# (1424, 'rocko')
# (1425, 'brandy')
# (1426, 'alborosie')
# (1427, 'porn')
# (3016084, 'badchieff-edo-saiya-cro')
# (1429, 'marky-mark-and-the-funky-bunch')
# (1430, 'indila')
# (1431, 'soprano')
# (1432, 'kano')
# (1574296, 'daniil')
# (1435, 'transplants')
# (1436, 'mc-ren')
# (1181083, 'mc-mental')
# (1443229, 'iv-jay')
# (1836444, 'ti-sto-jonas-blue-rita-ora')
# (2491803, 'rat-tv')
# (2885023, 'arthur-miguel')
# (132515, 'angel-olsen')
# (1444, 'jennifer-hudson')
# (1445, 'u-s-d-a')
# (1447, 'norah-jones')
# (3016105, 'vesna-zmijanac')
# (1450, 'yg')
# (1451, 'ras-kass')
# (1574315, 'faceless-1-7')
# (525741, 'janji')
# (1181104, 'rich2litt')
# (525745, 't-rfisk')
# (1836465, 'ivy-wells')
# (1459, 'novi-novak')
# (1460, 'red-hot-chili-peppers')
# (1463, 'plan-b-uk')
# (1464, 'chase-status')
# (1050039, 'linky-first')
# (394682, 'younotus')
# (394683, 'anna-naklab')
# (2885052, 'alan-walker-k-391-boy-in-space')
# (1469, 'jt-money')
# (3540409, 'big-topic')
# (1472, 'eli-porter')
# (1476, 'wax')
# (525764, 'natalia-przybysz')
# (1478, 'savage-rap')
# (1967558, 'dan-shay-justin-bieber')
# (1050056, 'boys-of-fall')
# (1574344, 'ugly-uk')
# (2491849, 'verpion')
# (1483, 'ugly-duckling')
# (1484, 'stromae')
# (525772, 'let-it-go')
# (1486, 'rich-kidz')
# (1487, 'thomas-hardy')
# (2360780, 'hannah-montana-iyaz')
# (2360782, 'zepkins')
# (2622925, 'danil-stepanov')
# (1492, 'nature')
# (3147221, 'maverick-city-musica-maverick-city-music')
# (1181143, 'young-mokuba-dat-adam')
# (1574359, 'xetonyl')
# (1497, 'artifacts')
# (2885080, 'marteria-tna-yasha')
# (1499, 'rage-against-the-machine')
# (263643, 'debbie-mathers-briggs')
# (1501, 'keith-murray')
# (1502, 'digable-planets')
# (2229727, 'paper-flowers-rus')
# (3147225, 'paris-paloma')
# (1505, 'nelly-furtado')
# (1507, 'sniper')
# (1508, 'nessbeal')
# (1509, 'k-young')
# (1510, 'chris-rock')
# (656871, 'glasond')
# (1312229, 'consoul-trainin')
# (1513, 'shyne')
# (1312231, 'lonelyrari')
# (1967589, 'paky')
# (1050092, 'gucci-boyy')
# (1517, 'flight-of-the-conchords')
# (525805, 'hirie')
# (1519, 'kesha')
# (656878, 'unboxholics-sakis-karpas')
# (1521, 'bashy')
# (1312236, 'yung-whxte')
# (1525, 'amy-winehouse')
# (525814, 'tino-martin')
# (1529, 'missy-elliott')
# (1530, 'common-market')
# (1531, 'david-dallas')
# (1705469, 'han-sara')
# (1443326, 'silvana-imam')
# (1535, 'john-cena')
# (1536, 'lil-keke')
# (394751, 'golqm-yus')
# (1312258, 'bigidagoe')
# (1539, 'outasight')
# (1540, 'trademark-da-skydiver')
# (1541, 'total')
# (1967621, 'pia-mia-carnage-gunna')
# (2360833, 'uniq-poet-reverb-dust')
# (1545, 'qusai')
# (1546, 'new-boyz')
# (1549, 'krs-one-marley-marl')
# (1550, 'homebrew')
# (1551, 'lights')
# (1552, 'rucka-rucka-ali')
# (1553, 'the-alchemist')
# (1554, 'salt-n-pepa')
# (1555, 'havoc')
# (656910, 'i-zah')
# (1557, 'aaliyah')
# (1558, 'mellowhype')
# (2360852, 'mo3-kevin-gates')
# (2622992, 'vulf-umsy')
# (1564, 'yasmin')
# (1566, 'kid-rock')
# (1050151, 'worn-tin')
# (1576, 'sims')
# (1577, 'dessa')
# (1578, 'p-o-s')
# (394795, 'blv')
# (525867, 'joan-daus')
# (1581, 'linkin-park')
# (656936, 'jacob-forever')
# (1583, 'french-montana')
# (394800, 'drakeo-the-ruler')
# (1585, 'barenaked-ladies')
# (1586, 'rah-digga')
# (1836591, 'ilke')
# (1836594, 'mpho-sebina')
# (2360886, 'ksoo')
# (1593, 'aceyalone')
# (656955, 'immo-pr-nce-044')
# (1967678, 'capital-bra-samra-kalazh44')
# (1600, 'wretch-32')
# (1601, 'paul-mccartney')
# (1602, 'stevie-wonder')
# (1050178, 'raga')
# (1604, 'travis-barker')
# (1605, 'brand-nubian')
# (1967683, 'capital-bra-samra-santos')
# (1607, 'juice')
# (1608, 'esham')
# (2754120, 'kikimoteleba')
# (1610, 'al-green')
# (1611, 'yg-pushaz')
# (132683, 'ujot')
# (525901, 'the-half-brothers')
# (1050188, 'ztatik')
# (1312331, '67-r6-x-st-x-itch')
# (1574474, 'vonnie-d')
# (1617, 'baby-bash')
# (1574480, 'ril')
# (1619, 'bliss-n-eso')
# (1967692, 'kacper-blonsky')
# (2229844, 'larry-june-cardo')
# (1624, 'next')
# (1626, 'zilly')
# (1312348, 'blizzy-swe')
# (1629, 'petey-pablo')
# (1630, 'ciara')
# (1631, 'kid-ink')
# (1632, 'tory-lanez')
# (656990, 'c-arma')
# (1634, 'quan')
# (1050209, 'dipha-barus')
# (1181283, 'flipturn')
# (1312352, 'etnaise')
# (1638, 'aidonia')
# (1639, 'wiley')
# (656998, 'jerry-purpdrank')
# (1641, 'hurricane-chris')
# (132714, 'heatwave')
# (1443429, 'briston-maroney')
# (1644, 'one-be-lo')
# (1645, 'elvis-presley')
# (1181292, 'yigal-bashan')
# (657007, 'backstage-cast')
# (1648, 'rick-james')
# (1312366, 'harry-baker')
# (1650, 'odd-squad')
# (1443438, 'vintersea')
# (1312372, 'apollo-fresh')
# (1653, 'ryan-tedder')
# (1654, 'tommy-c-j-reyez')
# (1181301, 'tayc')
# (1656, 'harvey-j')
# (1705584, 'grimlxck')
# (3016306, 'lp2-0')
# (132731, 'el-far3i')
# (263803, 'nimeni-altu')
# (1661, 'edan')
# (1050237, 'roy-ricardo')
# (1663, 'hot-boys')
# (1664, 'the-temptations')
# (1665, 'machine-gun-kelly')
# (1050240, 'maquiny')
# (132739, 'bj-rnstjerne-bj-rnson')
# (1443455, 'trick-james')
# (2229892, 'french-the-kid')
# (1670, 'lil-troy')
# (1574535, 'gravedgr')
# (1050248, 'yura-yunita')
# (1181320, 'dizzyeight')
# (1967750, 'rosa-ansch-tz')
# (3016326, 'drake-yebba')
# (1676, 'hot-chip')
# (132749, 'mrozu')
# (1679, 'da-brat')
# (132751, 'zipera')
# (657041, 'alice-phoebe-lou')
# (1574544, 'x-sider')
# (1050259, 'n-hardem')
# (1684, 'youssoupha')
# (132757, 'the-psychedelic-furs')
# (657046, 'girli')
# (1705618, 'ritual-tove-styrke')
# (1688, 'ghetts')
# (657048, 'dj-xo')
# (1691, 'tom-waits')
# (1692, 'kool-keith')
# (1693, 'n-a-s-a')
# (1050269, 'rosa-pullman')
# (1695, 'john-frusciante')
# (394912, 'toki-asako')
# (657057, 'velli')
# (1836703, 'ero-kosi')
# (2885284, 'lil-zack1')
# (1701, 'sisq')
# (132773, 'fat-mizzo')
# (1443495, 'zino181')
# (1443496, 'ngela-torres')
# (2361001, 'honorary-astronaut')
# (1706, 'awa-imani')
# (525994, 'noam-kaniel')
# (1705642, 'yung-nigo-drippin')
# (1709, 'bobby-womack')
# (1710, 'kool-moe-dee')
# (657069, 'kate-linn')
# (1712, 'grand-corps-malade')
# (1713, 'skepta')
# (1714, 'anthony-hamilton')
# (526003, 'andy-williams')
# (132788, 'ian-anderson')
# (1050286, 'voodoo-j-rgens')
# (1312437, 'dolo-tonight')
# (1720, 'watsky')
# (263864, 'chaka-demus-pliers')
# (1705660, 'overlust')
# (1181373, 'gli-autogol')
# (1726, 'kreva')
# (3540671, 'zarcort-cyclo-samuel-barranco')
# (132800, 'fuzz-rico')
# (1050304, 'wiser')
# (1730, 'lykke-li')
# (1731, 'jill-scott')
# (132802, 'anna-calvi')
# (1836740, 'yeitsmebby')
# (1734, 'brokencyde')
# (526022, 'vanessa-bling')
# (2098881, 'quelle-chris-chris-keys')
# (1738, '60-second-assassin')
# (1739, 'odd-future')
# (1181389, 'm-huncho')
# (132814, 'onklp-de-fjerne-slektningene')
# (1743, 'natalie-portman')
# (1745, 'childish-gambino')
# (1746, 'tracy-chapman')
# (1749, 'chairlift')
# (1750, 'despo-rutti')
# (1751, 'k-flay')
# (1752, 'zion-i')
# (1753, 'keny-arkana')
# (526039, 'lasse-dahlquist')
# (1755, 'carlos-santana')
# (526042, 'gnome')
# (526044, 'haifa-wehbe')
# (1050327, 'kakora')
# (1312475, 'ardilla')
# (1443544, 'jd-pantoja')
# (2623201, 'zero-9-36-travis-barker-clever')
# (2623203, 'dj-muggs-x-rome-streetz')
# (3147491, 'kings-usa')
# (1766, 'mr-bigg')
# (657126, 'm-ria-rov')
# (2623208, 'enula')
# (1769, 'tq')
# (1770, 'iam')
# (2754284, 'epex')
# (657135, 'young-lex')
# (1050352, 'virux')
# (1181425, 'zeds-dead-illenium')
# (657138, 'kemal-palevi')
# (657139, 'dycal')
# (1780, 'ill-bill')
# (2492145, 'kevin-rold-n-jd-pantoja')
# (2885365, 'klywoodjeb')
# (526071, 'ruen-brothers')
# (1786, 'cannibal-ox')
# (1787, 'pixies')
# (1788, 'ratatat')
# (395005, 'jorge')
# (1836794, 'yung-xander')
# (1705727, 'zedd-katy-perry')
# (2492159, 'andr-de-shields-hadestown-original-broadway-company')
# (395009, 'elgit-doda')
# (2623233, 'jay-roxxx')
# (1574662, 'franky-kuncoro')
# (1799, 'enur')
# (2885382, 'chyng-diamond')
# (3016454, 'eline-noelia')
# (1802, 'smif-n-wessun')
# (657162, 'mr-eazi')
# (1804, 'the-rej3ctz')
# (1705739, 'uppbeat')
# (1806, 'ali-lunatic')
# (2754315, 'mckenna-grace')
# (3016456, 'frode-vassel')
# (1809, 'reks')
# (1810, 'jesse-mccartney')
# (1811, 'magnolia-shorty')
# (2098963, 'xhris2eazy')
# (1813, 'the-jacka')
# (1574677, 'isaia-huron')
# (1815, 'dolla')
# (1312535, 'oliverse')
# (2754321, 'theodd1sout-roomie')
# (1818, 'chevy-woods')
# (1819, 'b-g')
# (1574682, 'zoeepoppy')
# (1821, 'professor-elemental')
# (1822, 'good-charlotte')
# (1823, 'daddy-yankee')
# (657181, 'john-connor')
# (2230045, '2tenrecords')
# (2885403, 'bizarrap-paulo-londra')
# (657187, 'christine-ebersole')
# (1312547, 'chernaya-ekonomika')
# (1443620, 'honk-the-musical-original-cast')
# (2885406, 'imanisaka')
# (1181479, 'aj-hernz')
# (1836839, 'lissom')
# (1836, 'louis-logic')
# (1181484, 'navia-robinson')
# (1838, 'ellie-goulding')
# (1181485, 'isaac-ryan-brown')
# (3540782, 'jess-conte')
# (1443635, 'domlaike')
# (526132, 'in-the-heights-original-cast-recording')
# (1836853, 'golec-uorkiestra-gromee')
# (1846, 'salif')
# (657206, 'knucks')
# (1181496, 'richaadeb')
# (1849, 'earlly-mac')
# (2492212, 'andr-de-shields-reeve-carney-jewelle-blackman-yvette-gonzalez-nacer-kay-trinidad-timothy-hughes-malcolm-armwood-jessie-shelton-kimberly-marable-khaila-wilcoxon-ahmad-simmons-afra-hines-t-oliver-reid-john-krause')
# (1851, 'fam-lay')
# (1853, 'joss-stone')
# (1574717, 'mandems')
# (2754366, 'noriel-manuel-turizo')
# (1858, '8ball-mjg')
# (1574723, 'rufus-t-firefly')
# (1443652, 'icton')
# (1861, 'willie')
# (2361157, 'capital-bra-sdp')
# (1863, 'outerspace-duo')
# (2361162, 'capital-bra-sido')
# (1867, 'audio-two')
# (1870, 'ya-boy')
# (1871, 'projota')
# (526158, 'blank4')
# (1875, 'h-magnum')
# (1877, 'sinik')
# (1878, 'ransom')
# (1050455, 'doble-porci-n')
# (1880, 'mack-10')
# (1882, 'brav')
# (1883, 'tiers')
# (1443674, 'victoria-voss')
# (657245, 'sam-tinnesz')
# (1886, 'fat-boys')
# (395104, 'felix-jaehn')
# (1705825, 'zoran-umadinac')
# (526178, 'urban-contact')
# (395107, 'zbigniew-wodecki')
# (1050467, 'jun-togawa')
# (1893, 'gwen-stefani')
# (1894, 'the-ranger')
# (1895, 'chicago-bears-shufflin-crew')
# (1896, 'marques-houston')
# (1897, 'kenny-loggins')
# (1898, 'brooke-valentine')
# (1899, 'homicide')
# (657253, 'ezzari')
# (1050475, 'despo')
# (1705836, 'the-doorbeen')
# (2099049, '2-0-visions')
# (2492266, 'reeve-carney-eva-noblezada-andr-de-shields-afra-hines-timothy-hughes-kimberly-marable-john-krause-ahmad-simmons')
# (2492267, 'reeve-carney-eva-noblezada-afra-hines-timothy-hughes-john-krause-ahmad-simmons-kimberly-marable')
# (2492271, 'reeve-carney-andr-de-shields')
# (1907, 'casey')
# (1908, 'rohff')
# (3540846, 'krabboy')
# (1912, 'funkmaster-flex')
# (526201, 'pritam-rekha-bhardwaj')
# (2885498, 'apashe-lubalin')
# (3147642, 'israyl')
# (1967997, 'marcianeke')
# (2492288, 'berry-good-man')
# (3016576, 'cazzu-la-joaqui')
# (1924, 'dee-1')
# (395141, 'hatikva-6')
# (2885511, 'usain-bolt-nj')
# (1050504, 'irishtoothache')
# (1836938, 'viking-barbie')
# (3016586, 'matteo-paolillo-icaro')
# (1932, 'vita')
# (526221, 'veldentaal')
# (657292, 'the-tide')
# (1937, 'fabe')
# (1938, 'hocus-pocus')
# (657299, 'qustodi-del-tempo')
# (2492305, 'tay-g-tayg1312')
# (2099093, 'epr-iyer')
# (2099095, 'tim-ricis')
# (1945, 'lunatic')
# (1946, 'lino')
# (1947, 'oxmo-puccino')
# (1948, 'x-men')
# (1949, 'marilyn-monroe')
# (526233, 'buscabulla')
# (657311, 'duwap-kaine')
# (395168, 'kid-c')
# (1443738, 'introvert')
# (1705886, 'esteban')
# (1955, 'bj-the-chicago-kid')
# (1312676, 'splean')
# (2492318, 'yg-gunna')
# (1958, 'klub-des-loosers')
# (526247, 'nathaniel-rateliff-the-night-sweats')
# (395176, 'rainbow-kitten-surprise')
# (1961, 'akhenaton')
# (1312679, 'matxx')
# (1963, 'don-choa')
# (1964, 'le-rat-luciano')
# (1574826, 'in-living-color')
# (2361254, 'minmini')
# (1967, 'shurik-n')
# (2492328, 'unknown-reference-singer')
# (395185, 'xcep')
# (1970, 'les-sages-po-tes-de-la-rue')
# (1971, 'hern-ni')
# (133043, 'panda')
# (1973, 'smoke-dza')
# (1974, 'damon-albarn')
# (2099124, 'robyn-ottolini')
# (657336, 'lazer-mmz')
# (3409847, 'ya-uk')
# (3540922, 'babybeezy')
# (1050555, 'tipsi-tip')
# (2230204, 'pepel-nahudi')
# (1981, 'audio-push')
# (1050559, 'astrid')
# (1984, 'emanny')
# (1985, 'frank-ocean')
# (1050560, 'max-korzh')
# (526275, 'rolf-just-nilsen')
# (1312707, 'krimelife-ca')
# (1574851, 'ayce-comet')
# (1990, 'russell')
# (526280, 'i-boys-della-nord')
# (1993, 'roy-jones-jr')
# (2885576, 'abdullah-siddiqui-talha-anjum')
# (1995, 'shaquille-o-neal')
# (1181644, 'yusei')
# (3278793, 'defkhan-ehin-ah')
# (3278796, 'yankee34')
# (2001, 'tamia')
# (2002, 'mike-g')
# (1574867, 'skeletortilla')
# (2004, 'rockin-squat')
# (2005, 'peter-bjorn-and-john')
# (1705940, 'hulvey')
# (1574872, 'john-burnside')
# (2009, 'hotstylz')
# (2011, 'casey-veggies')
# (2012, 'classified')
# (2013, 'p-m-dawn')
# (657374, 'shaa-bigga')
# (2015, 'khalil')
# (1705951, 'v-yaav')
# (1968092, '88rising-rich-brian-chung-ha')
# (3147743, 'yellow-claw-weird-genius-novia-bachmid')
# (2020, 'rocca')
# (2623463, 'yungrico')
# (2024, '88-keys')
# (1968104, 'pvnterv-roully')
# (2026, 'macklemore')
# (526314, 'teen-beach-movie-cast')
# (2028, 'martin-luther-king-jr')
# (2029, 'train')
# (2030, 'new-edition')
# (526315, 'what-do-i-stand-for')
# (2032, 'die-antwoord')
# (657393, 'the-cactus-blossoms')
# (1050607, 'kshmr-marnik')
# (2035, 'g-unit')
# (2036, 'ideal-j')
# (2037, 'heavy-metal-kings')
# (657397, 'it-looks-sad')
# (526327, 'kevin-turk')
# (1050615, 'key-largo')
# (2041, 'emilio-rojas')
# (2042, 'benefit')
# (1181686, 'sprite-lee')
# (2044, 'eyedea')
# (1574903, 'ros-barber')
# (2046, 'dj-kay-slay')
# (2047, 'heiruspecs')
# (2048, 'mc-lyte')
# (2049, 'ab-soul')
# (133122, 'george-ezra')
# (133123, 'wilkinson')
# (2052, 'omarion')
# (2053, 'leo')
# (657413, 'only1tipy')
# (2055, 'alkaline-trio')
# (1705986, 'sozvezdie-otrezok')
# (2057, 'hoodie-allen')
# (1574922, 'pacho-daddy-yankee-bad-bunny')
# (1181708, 'robert-finley')
# (3147788, 'cuco-dannylux')
# (2064, 'dan-black')
# (2065, 'marilyn-manson')
# (133138, 'jamie-lenman')
# (2069, 'calvin-harris')
# (2070, 'mysonne')
# (2071, 'hollywood-undead')
# (133142, 'las-ketchup')
# (2073, 'beck')
# (2074, 'dyme-a-duzin')
# (2075, 'dumbfoundead')
# (2076, 'prince-ea')
# (133145, 'simply-red')
# (2078, 'pilot')
# (2079, 'kennedy')
# (3016733, 'nanashi-mumei')
# (3147801, 'cuco-adriel-favela')
# (3147808, 'barney-sku')
# (2083, 'tiron')
# (2086, 'collie-buddz')
# (657446, 'dutch-revz')
# (1050664, 'entheos')
# (2089, 'viarritz')
# (2090, 'prince-paul')
# (526379, 'hot-since-82')
# (2092, 'quasimoto')
# (526381, 'r-f-s-du-sol')
# (2094, 'kalenna')
# (1050665, 'flatland-cavalry')
# (1968172, 'nbsplv')
# (133170, 'sun-kil-moon')
# (1050674, 'zuna-miami-yacine')
# (1837106, 'planet-1999')
# (526390, 'brooke-eden')
# (1050681, 'kaitlin-butts')
# (133178, 'gary-wilson')
# (1443900, 'viandra')
# (133181, 'robert-c-tucker')
# (2110, 'kutt-calhoun')
# (657470, 'gizmo-varillas')
# (2112, 'krizz-kaliko')
# (2113, 'lyn-collins')
# (3541059, 'yenesi-myuko')
# (133188, 'a-f-r-o')
# (526404, 'jonathan-david-helser-melissa-helser')
# (1574981, 'ani-rus')
# (2121, 'heavy-d')
# (2122, 'janet-jackson')
# (2123, 'minist-re-a-m-e-r')
# (2126, 'amel-larrieux')
# (526414, 'we-are-young')
# (1181775, 'longguo-sihyun')
# (395345, 'khaotic')
# (657489, 'nastra-x-needow')
# (2131, 'laze')
# (1050707, 'dom-fera')
# (2099280, 'friiiday-white-punk')
# (2137, 'tiara-thomas')
# (657504, 'fyb')
# (2145, 'goldie-lookin-chain')
# (1706083, 'ida-prester')
# (2149, 'johnny-polygon')
# (657510, 'zweierpasch')
# (1968229, 'vivasvan-vishahk')
# (2885736, 'mm44-turbo-shitpost-machine')
# (2099305, 'massaka-joe-young')
# (2155, 'flynt')
# (2156, 'scred-connexion')
# (1181804, 'umut-timur')
# (1837166, 'viking-death-trap-exe')
# (2623599, 'lucio101-omar101')
# (3147885, 'oh-caraga-gustav')
# (3147887, 'natalia-krakowiak')
# (1050741, 'pineapple-stormtv')
# (1050743, 'clyde-the-mack')
# (2169, 'black-kent')
# (657529, 'cine-team')
# (526460, 'oompa-loompa-cast')
# (1050750, 'yrn-murk')
# (2175, 'grieves')
# (1181823, 'oel')
# (2361472, 'youngstarbrazy')
# (2885758, 'ini')
# (264324, 'ruby-bridges-foundation')
# (1837188, 'nerissima-serpe')
# (2183, 'the-kings-dead')
# (1050759, 'ace-tee')
# (2187, 'horseshoe-g-a-n-g')
# (1181835, 'psihotrop')
# (2193, 'asheru')
# (2194, '9th-wonder')
# (3541137, 'behm-olavi-uusivirta')
# (2197, 'future')
# (2198, 'yung-chris')
# (526486, 'marama')
# (2200, 'tandem')
# (2205, 'goapele')
# (2206, 'flipsyde')
# (2207, 'shwayze')
# (2208, 'xian')
# (2209, 'j-live')
# (526496, 'vinyl-pinups')
# (2211, 'buck-65')
# (1050782, 'yid')
# (2213, 'flipmode-squad')
# (1050783, 'noah-lunsi')
# (2215, 'robbie-williams')
# (2216, 'young-roddy')
# (2217, 'field-mob')
# (264359, 'the-cheetah-girls')
# (2219, 'friedrich-schiller')
# (2220, 'ludwig-van-beethoven')
# (1444011, 'ekali-medasin')
# (1575080, 'tha-sergn')
# (2223, 'dosseh')
# (2224, 'avril-lavigne')
# (264367, 'glenn-medeiros')
# (2226, 'fredro-starr')
# (264368, 'bryson-tiller')
# (264369, 'zach-servis')
# (657583, 'romes')
# (657587, 'mc-pat-flynn')
# (2231, 'the-click')
# (1050803, 'russ-millions')
# (2233, '3lw')
# (526522, 'haute')
# (1575093, 'besomorph')
# (2236, 'kirko-bangz')
# (1706168, 'mc-virgins')
# (264382, 'nizio')
# (1837247, 'ingrid-alberini')
# (264384, 'empy')
# (264385, 'lehmber-hussainpuri')
# (526530, 'olivia-noelle')
# (2230463, 'taimour-baig')
# (1968324, 'payal-dev-jubin-nautiyal')
# (2099396, 'ostan-stars')
# (2361540, 'elenko-week')
# (2492607, 'immi')
# (2248, 'tunisiano')
# (2249, 'ol-kainry')
# (264394, 'odie')
# (1050827, '30-uk')
# (2252, 'disiz')
# (2253, 'raheem-devaughn')
# (2254, 'd-why')
# (2255, 'gruff-rhys')
# (1312970, 'kamil-pivot')
# (2257, 'young-noble')
# (526546, 'dl-downer')
# (264403, 'bonde-da-stronda')
# (2260, 'dj-premier')
# (264404, 'dennis-dj')
# (264405, 'ha-ha-tonka')
# (526548, 'olwik')
# (264408, 'old-man-canyon')
# (526550, 'travis-atreo')
# (2266, 'free-marie-antoinette-wright')
# (1181915, 'tauro-boys')
# (1444059, 'kikuo')
# (2269, 'wooh-da-kid')
# (2270, 'd-angelo')
# (1575127, 'daniela-darcourt')
# (526560, 'ivan-torrent')
# (1181920, 'akhil')
# (2274, 'remy-ma')
# (133347, 'fantasy')
# (264419, 'only-real')
# (2492640, 'buddy-castle')
# (2278, 'young-sam')
# (3410151, 'matilda-the-musical-original-cast')
# (1837288, 'yanez-yung-puggioni')
# (3541216, 'marco-mengoni-elodie')
# (2286, 'gunplay')
# (2287, 'the-hood-internet')
# (2230510, 'ultraflex')
# (657651, 'norman-perry')
# (1444086, 'pjotr')
# (2295, '213')
# (2298, 'doc-gyn-co')
# (2299, 'none')
# (2300, 'adele')
# (2301, 'gnarls-barkley')
# (526586, 'wolfgang-black')
# (1968383, 'johannes-oerding-ina-m-ller')
# (2304, 'rebecca-black')
# (1313024, 'jado-pvg')
# (1050883, 'hello-meteor')
# (1050884, 'murovei')
# (2309, 'kno')
# (1050885, 'jugo-rdens')
# (3279108, 'haloday')
# (1444104, 'lil-wayne-wiz-khalifa-imagine-dragons-logic-ty-dolla-ign')
# (2313, 'guilty-simpson')
# (2314, 'young-skeptics')
# (1444105, '1415')
# (2316, 'ade')
# (1444108, 'skrillex-rick-ross')
# (2318, 'sir-michael-rocks')
# (2319, 'nujabes')
# (2320, 'ghostpoet')
# (1706252, 'tyga-g-eazy-rich-the-kid')
# (2188793, 'xanndr')
# (264468, 'wall-of-voodoo')
# (2325, 'low-g')
# (526614, 'golden-mahogany-lox-golden-mahogany-lox')
# (1706260, 'global-azn')
# (2329, 'v-v-brown')
# (1706268, 'rost-s-szabika')
# (1444127, '74-fast-alberto-oy74')
# (2336, 'racionais-mc-s')
# (2337, 'kenna')
# (526624, 'alain-delon-dalida')
# (2341, 'kevin-cossom')
# (1181990, 'roachmg777')
# (2344, 'skinny')
# (1050920, 'elic')
# (2351, '2-bal-2-neg')
# (1050927, 'sincewhen')
# (1444143, 'billie-eilish-khalid')
# (2492722, 'eva-noblezada-reeve-carney')
# (2355, 'king-fantastic')
# (3148084, 'garri-topor-toni-raut')
# (2358, 'the-weeknd')
# (1182007, 'ikke-h-ftgold-vfl-eschhofen')
# (3017016, 'oda-gondrosen')
# (2361, 'stephen-marley')
# (2362, 'mavado')
# (133434, 'j-spades')
# (1050940, 'dan-murray')
# (1706297, 'valcos-chris-linton')
# (1444158, 'vice-tur')
# (3148095, 'gabriel-valenciano')
# (1837376, 'rami-swe')
# (2361664, 'xavierrr')
# (1575236, 'daoir-farrell')
# (2373, 'st-vincent')
# (1706310, 'capolow')
# (2099525, 'instinto-26')
# (2380, 'dot-rotten')
# (133455, 'rayven-justice')
# ...
# (2751208, 'lovv66-mayot')
# (2751209, 'lovv66-lovesomemama')
# (2751210, 'lovv66-seemee')
# (2751212, 'lovv66-mayot-seemee')
# (1571566, 'mk-jonas-blue-becky-hill')
# (3275500, 'honeythehustler')
# (2813313, 'matxx-candy-flip-boy-kipish-v-ghetto')
# (1536787, 'insecure-men')
# (1309433, 'rob-vicious')
# (391935, 'gary-portnoy')
# (3406592, 'gucci-mane-kodak-black')
# (2226945, 'idk-cutno')
# (1702658, 'xxxdragonxxx')
# (3144454, 'young-nudy-babydrill')
# (2226951, 'ultima-frontiera')
# (1440520, 'vincent-bueno')
# (1047305, 'ibo-diab')
# (391946, 'hound-dog')
# (2751243, 'bad-bunny-luar-la-l')
# (1047308, 'young-smokes')
# (391949, 'vikingarna')
# (391950, 'bugoy')
# (1702669, 'nizar-zgheib-aka-abs')
# (654096, 'kk-vishal-dadlani-neeti-mohan-shankar-mahadevan')
# (1440529, 'ambar-lucid')
# (391954, 'andien')
# (2489101, 'anonimus-lenny-tav-rez-jay-wheeler')
# (523029, 'fr-ro-delavega')
# (1440534, 'wifisfuneral-robb-bank')
# (3013397, 'frenchii-2x')
# (3013404, 'lampabikt')
# (391969, 'c-bool')
# (654115, 'accidents')
# (523044, 'jordan-feliz')
# (1833769, 'kempel')
# (2751274, 'lovv66-thrill-pill')
# (1047340, 'ellie-the-last-of-us-2')
# (391981, 'iaxe')
# (523054, 'theodore-shapiro')
# (1964845, 'yuranis-le-n')
# (2751277, 'pretty-scream-boulevard-depo')
# (1702706, 'ciro')
# (3013426, 'fireboy-dml-and-ed-sheeran')
# (654132, 'palm')
# (1440564, 'overstreet')
# (1964853, 'casar')
# (1964854, 'daneidy-barrera')
# (2620215, 'zhalarina')
# (2751289, 'tdd-mukka')
# (391995, 'clair-marlo')
# (1309507, 'remember-of-today')
# (129864, 'marc-shaiman')
# (129865, 'lucian-piane')
# (523082, 'inland-sky')
# (1309515, 'vadim-samoylov')
# (3275595, 'lil-gnar-chief-keef')
# (392013, 'tanju-okan')
# (2751309, 'unknown-u-s')
# (129871, 'daniel-kim')
# (654159, 'olga-bell')
# (1309519, 'sidhu-moosewala')
# (1702741, 'berner-mozzy')
# (1964886, 'tri-tipa')
# (1047383, '1-amvrka')
# (1833819, 'instasamka')
# (1964891, 'doll-ia')
# (2095964, 'wax-mustang')
# (392031, 'glen-washington')
# (523104, 'nitro-fun')
# (2882401, 'venjent')
# (2227042, 'ffshore')
# (1571685, 'ezra-collective')
# (1571688, 'ashlee-evan')
# (392042, 'far-apart')
# (523118, 'thomas-helmig-s-s-fenger')
# (1047407, 'prince-and-3rdeyegirl')
# (1702767, 'darshan-raval')
# (3275636, 'real-boston-richey-kodak-black-lil-crix')
# (1571701, 'j-howell')
# (3144565, 'officalkirai')
# (1833847, 'offica')
# (1047416, 'muscadine-bloodline')
# (129914, 'tim-buckley')
# (1047420, 'almost-famous')
# (2751358, 'katanacss-aikko')
# (2751360, 'katanacss-roky')
# (1440643, 'elise-ecklund')
# (1440652, 'pretty-savage')
# (2620301, 'playboi-flaros')
# (1440654, 'future-teens')
# (1702798, 'why-berry')
# (1833870, 'yase')
# (2227087, 'thee-sacred-souls')
# (392082, '2cellos')
# (392083, 'eddie-redmayne')
# (3275666, 'yeruza-yovngchimi-hydro')
# (1440661, 'qzeng')
# (2227093, 'sangiovanni')
# (1309591, 'obladaun')
# (3013527, 'gaodagamo-nesvyat')
# (1833882, 'quivers')
# (129947, 'tay-capone')
# (129951, 'keali-i-reichel')
# (654239, 'alitiz')
# (1440678, 'kakaiboys')
# (392103, 'tom-felton')
# (1440681, 'vivienne-chi')
# (1571753, 'polo-g-a-k-a-mr-dotoomuch')
# (1833897, 'high-zoey')
# (3275698, 'l-s-dunes')
# (3275700, 'hardy-lainey-wilson')
# (129973, 'soul-intent')
# (2882486, 'nensy-kholod')
# (2489271, 'camilo-el-alfa')
# (392122, 'ian-yates')
# (1178562, 'yawns')
# (392136, 'ron-moody')
# (2358220, 'feid-dalmata')
# (523216, 'scott-bradlee-s-postmodern-jukebox')
# (523221, 'hampster-dance-masters')
# (2096089, 'barbarela')
# (3275738, 'seventeen-anne-marie')
# (523230, 'bj-rnskov')
# (130015, 'kenneth-whalum')
# (1047519, 'vyok')
# (2620384, 'krbk')
# (392164, 'dennis-waterman')
# (1047525, 'agar-agar')
# (1047528, 'ferrari-jackson')
# (392169, 'gucci-mane-rich-homie-quan')
# (130026, 'themind')
# (1047530, 'soraia-ramos')
# (1178600, 'blu-exile')
# (1702889, 'hikaru-utada-skrillex')
# (1702893, 'k-suave')
# (2751474, 'the-kid-laroi-marshmello')
# (130035, 'illionaire-records')
# (261107, 'piruka')
# (1178614, 'double-g-records')
# (1178617, 'original-cast-of-freaky-friday-the-musical')
# (1178618, 'raelee-nikole')
# (130043, 'tobu')
# (2358265, 'gianluca-vacchi-ir-sais')
# (2751487, 'veysel-kontra-k')
# (1047552, 'glr-gusto')
# (3568864, 'xanobi')
# (392203, 'planet-giza')
# (1702924, 'kevin-fret')
# (2751499, 'sha-ek')
# (2751502, 'yung-van-guardin')
# (2620432, 'lilboi-wonstein')
# (523291, 'novo-amor-ed-tullett')
# (392220, 'feli')
# (1309725, 'vais')
# (1965087, 'karol-g-jessie-reyez')
# (1440800, 'jihyo')
# (2882592, 'mark-ambor')
# (1047586, 'ruben-young')
# (1440805, 'ikkubaru')
# (2096165, 'em-lija-sama')
# (2620457, 'fuwa-minato')
# (1440810, 'nightcove-thefox')
# (2751530, 'natalie-jane')
# (2620460, 'inas-mike-ride')
# (2188138, 'yer')
# (1047604, 'hkfiftyone')
# (1178686, 'kokab')
# (392255, '4-mc-s')
# (261185, 'david-hasselhoff')
# (392258, 'adna')
# (1047617, 'kwollem')
# (2882628, 'gold-necklace')
# (523335, 'marija-erifovi')
# (2489420, 'italia-90')
# (2096208, 'em-beihold')
# (1047634, 'greywind')
# (1178709, 'flying-decibels')
# (261207, 'history-in-the-making')
# (1047646, 'chikara')
# (130145, 'romy')
# (2096231, '22-7-nanabun-no-nijyuuni')
# (1309801, 'the-ninth-wave')
# (1178731, 'we-are-fury')
# (2751595, 'hvnds')
# (1440878, 'herra-ylpp')
# (1834099, 'vito-bianco')
# (2882676, 'vesna-vukeli-vendi')
# (2489468, 'nhoj')
# (130173, 'gaeko')
# (654462, 'youngster-jiji')
# (261249, 'whigfield')
# (2751619, 'foreign-eli')
# (261253, 'rival-sons')
# (3275909, 'verareyouu-valyuta-skuratov-verareyouu')
# (261261, 'nah')
# (1703056, 'natalia-lacunza-miki-n-ez')
# (1309843, 'tudubom-records')
# (261268, 'noosa')
# (1178772, 'hoseah-partsch')
# (261272, 'accept')
# (1965211, 'vagonodrivers')
# (1440935, '2bunny')
# (2227371, 'kool-savas-mel')
# (1834160, '44phantom')
# (2358449, 'fresh-ladouille')
# (261298, 'vicious-rumors')
# (3013815, 'digbargayrapss')
# (1834168, 'tristan-taylor')
# (1047738, 'pi-erre-bourne')
# (523452, 'flora-ofelia')
# (1178814, 'lost-dog-street-band')
# (1440959, 'quarto-blocco')
# (1178817, 'tutweezy')
# (392386, 'primo-squarta')
# (1440964, 'tuna-ipek')
# (654533, 'ollie-joseph')
# (2751686, 'indie-tribe-dj-mykael-v-jon-keith')
# (1047751, 'kyle-exum')
# (1440973, 'international-music-deutsch')
# (261332, 'emir-kusturica-the-no-smoking-orchestra')
# (2489557, 'the-qwackers')
# (261336, 'hotboycaleb')
# (654552, 'jeremy-renner')
# (1440986, 'lee-hong-gi-yoo-hwe-seung')
# (3013852, 'craig-wedren-anna-waronker')
# (1440993, 'lunay')
# (2358505, 'don-v-asme')
# (1834219, 'juanfran')
# (1178860, 'ovrkast')
# (2751725, 'indie-tribe-nobigdyl-dj-mykael-v')
# (2751726, 'indie-tribe-jon-keith-mogli-the-iceburg')
# (2227444, 'naxowo')
# (654583, 'anna-akana')
# (654589, 'terror-jr')
# (3538175, 'summer-cem-abra-cadabra-uzi')
# (3013889, 'kinny-zimmer-quebonafide')
# (2227459, 'helabroke')
# (1965317, 'oktavia')
# (523528, 'portion-boys')
# (3144971, 'henny-popov')
# (1703187, 'lil-cake')
# (1047829, 'king-raam')
# (1047830, 'eendo')
# (130327, 'y2am')
# (1441047, 'mason-ramsey')
# (1441050, 'webbie-joeazzy')
# (654619, 'flora-cash')
# (1178912, 'lowly-god')
# (130339, 'alaine')
# (1178915, 'dead-posey')
# (2227493, 'riovaz')
# (1047846, 'hans-pl')
# (1441063, 're-pac')
# (2620710, 'kerimcan-durmaz')
# (1572137, 'dcvdns-tamas')
# (2751780, 'ktlyn')
# (1178924, 'fake-laugh')
# (1834284, 'uxknow-skanko')
# (2751788, 'eminem-jack-harlow-cordae')
# (3013936, 'blxst-tyga')
# (2751793, 'juice-armani')
# (523570, 'element-animation')
# (654644, 'red-vox')
# (1047861, 'janine-te-oso')
# (2358580, 'queen-wa-abii')
# (1834295, 'iamjugo')
# (654648, 'kingdm')
# (2358583, 'undacava-jason')
# (2358584, 'bobby-vandamme')
# (2358585, 'hayalet-btc')
# (2751797, 'rob49')
# (2620737, 'lenny-tav-rez-brytiago')
# (1703234, 'zane-burko')
# (130376, 'amara')
# (1047881, 'neovaii')
# (3538250, 'pommelien-thijs-kaat-thijs')
# (1703244, 'mc-fahah')
# (2620750, 'jesenia')
# (1834319, 'teksidr')
# (1572176, 'lary-over-l-rico-en-la-casa')
# (523601, 'izabell')
# (654673, 'cairokee')
# (3145046, 'ji-chang-wook-choi-sung-eun')
# (130391, 'mississippi-john-hurt')
# (2489690, 'bini')
# (392539, 'geno')
# (523611, 'vilma-alina')
# (523612, 'luigi-21-plus')
# (1965404, '79angels')
# (2227549, 'voice-of-baceprot')
# (2358620, 'mouh-milano')
# (2489692, 'zetatestoprova')
# (1441126, 'conor-matthews')
# (2227558, 'joell-ortiz-kxng-crooked')
# (3013993, 'namplevet-ogbully-rolso-jefe')
# (2882925, 'amaarae-moliy')
# (3538288, 'ze2-oskido-young-stunna')
# (130417, 'wave-chapelle')
# (1441139, 'violet-cold')
# (1310072, 'namewee')
# (1310073, 'meu-ninomiya')
# (130426, 'basshunter')
# (1834362, 'esther-graf')
# (523645, 'the-u-s-army-airborne')
# (1310077, 'two-22')
# (1572223, 'amy-guti-rrez')
# (1441152, 'pastor-napas')
# (1703293, 'ator-untela-rojas-on-the-beat-young-eiby')
# (2358663, 'clean-bandit-mabel')
# (523656, 'raylee')
# (1441161, '8ruki')
# (130443, 'snik')
# (130449, 'tagtraeumer')
# (1703313, 'xladnokrovniy')
# (2227605, 'yourlocalmidget')
# (1310104, 'snoop-zone-2')
# (2620825, 'snelle-maan')
# (1441180, 'erika-henningsen')
# (130461, 'roxanne-shant')
# (1441181, 'original-broadway-cast-of-mean-girls')
# (1965471, 'ha-astra')
# (392608, 'wiley-from-atlanta')
# (2096541, 'gjesti')
# (2358688, 'samra-lune')
# (2358691, 'lune')
# (2620834, 'g4our-thrill-pill')
# (3145126, 'yani5000-lugatti-hak')
# (1047975, 'wifigawd')
# (1047976, 'diamondsonmydick')
# (1047977, 'conor-maynard-william-singe')
# (1703340, 'yoandri')
# (1965487, 'pual-saint')
# (3145139, 'n-krov-iz-nosa')
# (1703349, '3-o')
# (392634, '888-band')
# (1047996, 'endlich-august')
# (523710, 'kinderliedjes')
# (1047999, 'fullface')
# (1441215, 'timurka-bits')
# (1048006, 'patrickxblue')
# (1048008, 'blvth')
# (1441224, 'yoo-seon-ho')
# (130508, 'vonte-skinner')
# (1965520, 'idina-menzel-evan-rachel-wood')
# (1965521, 'josh-gad-kristen-bell-idina-menzel-jonathan-groff-cast-of-frozen-ii')
# (654806, 'hamburger-helper')
# (1572311, 'young-dumps')
# (523739, 'the-blue-stones')
# (1703388, 'original-television-cast-of-rent-live')
# (1441247, 'l-sung-krieg')
# (523744, 'oscar-danielson')
# (654816, 'm-me')
# (1310178, '4th-point')
# (3538406, 'mar-lucas-be-le-kenia-os')
# (1179124, '2baba')
# (2358774, 'aintnolie')
# (392695, 'chief-keef-fredo-santana')
# (523767, 'ystein-dolmen')
# (1310200, 'thakidd')
# (1834487, 'rae-rae')
# (2489848, 'z-e-martina-persic')
# (1048060, 'pretty-solero')
# (1441277, 'el-cherry-scom')
# (2883065, 'felix-jaehn-miksu-macloud')
# (3014143, 'bandopop-lil-baby')
# (2227712, 'charmaine-fong')
# (654849, 'ayax')
# (3276283, 'doggyland')
# (130568, 'carolus')
# (654860, 'akeem-jahat')
# (523793, 'igor-herbut')
# (1310229, 'matrang')
# (1441304, 'you-less')
# (2620955, 'ra-is-ngee')
# (3145243, 'joey-valence-brae')
# (523808, 'inger-lise-rypdal')
# (654881, '316')
# (654889, 'cranio-randagio')
# (130602, 'teezy-baby')
# (523818, 'xxxx')
# (2752044, '5000-gideon-trumpet-killdummies')
# (654894, 'enposib')
# (1572399, 'estelle-aj-michalka')
# (654900, 'urano')
# (130613, 'killing-joke')
# (654902, 'la-mafia-del-amor')
# (1965623, 'pimp-flaco-kinder-malo')
# (2620982, 'aikko-inspace')
# (2883130, 'savage-ga-p-mc-virgins')
# (3538492, 'xelena')
# (2620993, 'kazondabeat-monk')
# (1048131, 'molly-burch')
# (1179203, 'kdsouls')
# (2096707, 'tone-rapper')
# (2883141, 'tunechikidd-pablo-chill-e-marcianeke')
# (3145283, 'fumez-the-engineer-tight-road-baby')
# (3276355, 'zzzahara-mareux')
# (3407427, 'isah-hver-gang-vi-m-tes')
# (130634, 'jae-stephens')
# (3538513, 'queendom-puzzle')
# (523860, 'the-hu')
# (654932, 'lil-pump')
# (130646, '2virgins')
# (654933, 'vbs')
# (1572440, 'tobeyworld')
# (1572441, 'cro-trettmann-kitschkrieg')
# (1834589, 'black-v-neck')
# (3538527, 'loc-dog-atl')
# (1572448, 'xuitcasecity-mighty-riot')
# (2883168, 'enique-39th')
# (3014242, 'osamy-tezuka')
# (2358883, 'fkj-tom-misch')
# (3145319, 'universe-on-eunha')
# (1048168, 'ryugo-ishida')
# (654954, 'psycrow')
# (1834607, 'rich-dunk')
# (2227825, 'elhae-i-m')
# (3145330, 'fumez-the-engineer-hazey')
# (2096756, 'eden-isr')
# (3145332, 'yung-bredda')
# (2621049, 'giovanni-zarella-pietro-lombardi')
# (1572474, 'ybn-nahmir-ybn-cordae')
# (2883195, 'yagi-b')
# (1048189, 'locateemilio')
# (1572478, 'ybn-cordae-ybn-almighty-jay')
# (3538557, 'omah-lay-ozuna')
# (654980, 'relax-rekords')
# (2883207, 'lvaro-d-az-feid')
# (3538577, 'car-n-le-n-camilo')
# (392850, 'nick-land')
# (2358934, 'dcg-bsavv-dcg-msavv-dcg-shun')
# (2883224, 'innercut-natalia-lacunza-ghouljaboy')
# (2490010, 'icon-band')
# (655008, 'jayla-darden')
# (1048229, 'ngie')
# (655014, 'gmgb')
# (1703589, 'junkie-jungle')
# (261800, 'nai-palm')
# (1965737, 'tmcthedon')
# (2490021, 'dehao-zhang')
# (3021914, 'travma-rvmzes')
# (130733, 'nego-true')
# (523950, 'super-junior-k-r-y')
# (1703597, 'dollar-prync')
# (1834670, 'fairlane-zack-gray')
# (2096815, 'oimara')
# (2752177, 'poor-bishop-hooper')
# (261811, 'altana')
# (2227894, 'malome-vector')
# (1048251, 'sello-therapper')
# (1834683, 'ghouljaboy')
# (1441469, 'overmono')
# (2358974, 'victor-perez')
# (1572543, 'ollie-byrd')
# (130752, 'brett-dennen')
# (2883259, 'the-spirituals-choir')
# (655044, 'men-i-trust')
# (130761, 'vassendgutane')
# (1048265, 'total-ape')
# (1048268, 'goulam')
# (1441484, 'ivar-bj-rnson-einar-selvik')
# (261838, 'yung-hurn')
# (1179342, 'teminite')
# (2358991, 'hayley-gene-penner')
# (2358992, 'egor-kreed-the-limba')
# (2883279, 'pm-eldzhey')
# (1572565, 'the-bonfyre')
# (1441497, 'nigpro')
# (655066, 'michael-trapson')
# (392923, 'tommy-wiseau')
# (524002, 'mr-cool')
# (2096869, 'lillian-hepler')
# (1048296, 'wendy-x-moon-jung-jae-x-nile-lee')
# (3014378, 'babysantana-yvngxchris')
# (1048306, 'young-trap-kid')
# (2162228, '264connection')
# (2096887, 'anuel-aa-drake-future')
# (1834747, 'alissic')
# (655105, 'baby-b')
# (1965832, 'original-london-cast-of-juliet')
# (1703697, 'ovsyankin-slava-kpss')
# (2096913, 'elia')
# (1703699, 'shevchenko-elloco')
# (1834771, 'yxng-le')
# (524053, 'huntar')
# (655125, 'rizky-febian')
# (3014418, 'ismo-x-nass')
# (1834782, 'yung-lean-thaiboy-digital')
# (130847, 'jenifer')
# (1965856, 'riley-roth')
# (2752293, 'todd-cameron')
# (1441575, 'noir-korea')
# (1834792, 'alex-rose-rauw-alejandro')
# (1441581, 'agust-n-casanova')
# (2621232, 'ink-ire')
# (655153, 'd-or-et-de-platine')
# (3538739, 'blacflaco-korelon')
# (655156, 'good-morning')
# (1310517, 'maruv')
# (3014453, 'chinx-os')
# (1572663, 'tito-el-bambino-shelow-shaq-el-alfa')
# (1310520, 'maruv-boosin')
# (1048377, 'sapa13')
# (3145530, '3breezy-toosii')
# (2031985, 'ken-y-lenny-tav-rez')
# (1441603, 'the-longshot-band')
# (1572676, 'jagwar-twin')
# (1310533, 'jesse-y-joy-gente-de-zona')
# (1572677, 'zion-shadow-blow')
# (2490179, 'el-waili')
# (2883400, 'yung-gravy-trippythakid')
# (1048394, 'foxblood')
# (2031987, 'tunde-uk')
# (1048396, 'full-trunk')
# (1572685, 'fuego-lito-kirino')
# (1048398, 'woody-jackson')
# (261969, '1000mods')
# (2490194, '8-graves-unlike-pluto')
# (1048404, 'konrad-oldmoney')
# (655189, 'lotus-juice')
# (2621268, 'dj-snake-selena-gomez')
# (3538778, 'yovngchimi-dj-drama-g-herbo')
# (1048411, 'rendezvous-at-two')
# (524124, 'the-hat')
# (261981, 'raige')
# (655203, 'moha')
# (1572709, 'budman')
# (3014502, 'devito-nikolija')
# (3538792, 'toosii-21-savage')
# (1441642, 'dame-5')
# (130924, 'counterparts')
# (3276657, 'ian-beach-please')
# (524147, 'sel-uk-balc')
# (2621300, 'orchestra-of-jesus-christ-superstar')
# (2752371, 'zoommerbolozari')
# (3538803, 'nizi19-lucio101-omar101')
# (3538806, 'karbeats-mora-jhayco')
# (655229, 'las-bistecs')
# (524160, 'uzz')
# (3538816, 'snelle-kraantje-pappie')
# (262020, 'sworn-in')
# (1310598, 'aira-yuuki')
# (655239, 'saian-kara-al')
# (1048463, 'ynsf')
# (1048464, 'uthopia')
# (1179539, 'norton-hall-band')
# (262044, 'ernesto-cardenal')
# (1179549, 'lil-windex')
# (524190, 'kane-brown')
# (1572772, 'lil-pump-kanye-west')
# (130986, 'kempi')
# (2752426, 'itssdesire')
# (655277, 'pretty-vicious')
# (3014575, 'leonard-ibhadiyi')
# (130995, 'nobodys')
# (2097077, 'truviak')
# (1179576, 'brudi030')
# (2621370, 'alex-rose-rauw-alejandro-lenny-tav-rez-cazzu-lyanno')
# (3538876, 'horse-head-lil-tracy-nedarb-nagrom')
# (262077, 'hawk-nelson')
# (131009, 'tommy-walker')
# (262084, 'hoku')
# (2752454, 'pikone')
# (2097097, '4amcollective')
# (131018, 'duru-tha-king')
# (393164, 'jxnv')
# (1834958, 'yousef-hadaoui')
# (1048528, 'christian-burrows')
# (2883537, 'ofenbach-ella-henderson')
# (131026, 'dashiexp')
# (262099, 'wussy')
# (1834963, '2nd-life')
# (1703893, 'honey-moon-uk')
# (262109, 'battle-beast')
# (2883554, 'slava-marlow-hammali-navai')
# (262116, 'be-lakor')
# (131045, 'hurt-everybody')
# (131046, 'supa-bwe')
# (393189, 'rapido')
# (393194, 'kovacs')
# (1703914, 'itzy')
# (3538923, 'oscar-blesson-tyr')
# (393199, 'tina-campbell')
# (524271, 'rambo-amadeus')
# (655343, 'augustine')
# (2752495, 'nelccia')
# (393203, 'assy')
# (655347, 'd-savage')
# (1048565, 'du-boiz')
# (262134, 'natalie-cole')
# (3145721, 'yishark')
# (1572860, 'martin-garrix-justin-mylo')

# %%
# Close the connection
conn.close()
